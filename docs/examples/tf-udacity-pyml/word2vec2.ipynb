# %%
# These are ll the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
# %config InlineBackend.close_figures = False
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'
def maybe_download(filename, expected_bytes):
    """Dowload a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename +
                       '. Can you get it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as as list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0 # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])
for num_skips, skip_window in [(2,1), (2,2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels ['anarchism', 'originated', 'of', 'originated', 'abuse', 'of', 'first', 'abuse']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right
num_skips = 2 # How many times to reuse an input to generate a label
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    # Look up embeddings for inputs
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                    labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` methods will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += 1
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s, ' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()

# 이거 한글도 적용해보장 
print('process end')
# Out:
# Initialized
# Average loss at step 0: 1.000000
# Nearest to been: crowell,  sardinian,  fisheries,  partisans,  persists,  bingo,  loren,  kata,
# Nearest to nine: welling,  suites,  anaheim,  symonds,  bca,  esiason,  meritocracy,  rsa,
# Nearest to d: enslavement,  trisha,  aorta,  patrice,  nrc,  they,  haitian,  hyperinflation,
# Nearest to known: synod,  caer,  bony,  enosis,  geraldine,  unmolested,  jozef,  apologist,
# Nearest to not: democratique,  handmade,  pohl,  ducktales,  zagreb,  rangers,  symptom,  grundgesetz,
# Nearest to one: hoyle,  homeomorphism,  shocks,  gorgon,  rideau,  drowning,  interacts,  esr,
# Nearest to have: mich,  transmitted,  collectivization,  orton,  dispensation,  amplifiers,  separated,  viewer,
# Nearest to are: overdoses,  applying,  proud,  zambian,  guillain,  exponent,  chestnut,  malignant,
# Nearest to when: stol,  trichomes,  graal,  worthies,  ndp,  multiplied,  seeing,  inhumane,
# Nearest to be: newington,  loads,  presenting,  valentinians,  byron,  steamer,  inviting,  seimas,
# Nearest to people: taxi,  ancestries,  hillery,  refueling,  sangha,  kummer,  etiquette,  aristocrat,
# Nearest to b: decide,  torquato,  disasters,  ardennes,  distraught,  entry,  landlords,  ave,
# Nearest to state: skilful,  baryon,  hilary,  iana,  ayyubid,  bernardo,  microscopy,  gomoku,
# Nearest to between: worries,  naturalised,  eia,  crashing,  dib,  delirium,  skillfully,  bare,
# Nearest to had: sibm,  homogenized,  sens,  schwenkfeld,  mythologie,  agis,  frantic,  more,
# Nearest to such: benzoyl,  medi,  kyu,  democrats,  brabant,  timeout,  fur,  underrated,
# Average loss at step 2000: 1.000000
# Average loss at step 4000: 1.000000
# Average loss at step 6000: 1.000000
# Average loss at step 8000: 1.000000
# Average loss at step 10000: 1.000000
# Nearest to been: crowell,  sardinian,  were,  fisheries,  by,  kata,  carve,  be,
# Nearest to nine: eight,  seven,  six,  four,  five,  three,  one,  zero,
# Nearest to d: patrice,  nrc,  enslavement,  aorta,  haitian,  trisha,  keiretsu,  gays,
# Nearest to known: bony,  siberia,  enosis,  transnistrian,  reprising,  cube,  diamond,  jeremy,
# Nearest to not: mighty,  moors,  ducktales,  handmade,  guarantees,  libyans,  they,  more,
# Nearest to one: two,  six,  three,  five,  eight,  four,  seven,  nine,
# Nearest to have: had,  has,  are,  be,  mich,  properly,  were,  trapezohedron,
# Nearest to are: were,  is,  have,  retroactive,  do,  regan,  asparagales,  apolitical,
# Nearest to when: tells,  where,  after,  was,  theravada,  statuette,  as,  nascar,
# Nearest to be: have,  was,  by,  is,  elastic,  amor,  englewood,  api,
# Nearest to people: taxi,  expressionism,  counterattacks,  redistributed,  sangha,  noirs,  breakdowns,  burials,
# Nearest to b: jacky,  disasters,  entry,  distraught,  seven,  raster,  barley,  asphyxia,
# Nearest to state: hilary,  gomoku,  hyderabad,  mariner,  eastenders,  skilful,  baryon,  highschool,
# Nearest to between: with,  eia,  naturalised,  skillfully,  admissions,  worries,  ikeda,  dinar,
# Nearest to had: has,  have,  was,  were,  jericho,  inductive,  sixths,  sifra,
# Nearest to such: mallarm,  well,  different,  begged,  kyu,  ozark,  brabant,  domestic,
# Average loss at step 12000: 1.000000
# Average loss at step 14000: 1.000000
# Average loss at step 16000: 1.000000
# Average loss at step 18000: 1.000000
# Average loss at step 20000: 1.000000
# Nearest to been: be,  crowell,  become,  was,  were,  carve,  being,  ho,
# Nearest to nine: eight,  seven,  five,  six,  four,  zero,  three,  two,
# Nearest to d: nrc,  unaccustomed,  enslavement,  aorta,  vader,  patrice,  trisha,  dect,
# Nearest to known: such,  well,  siberia,  transnistrian,  bony,  used,  regarded,  ceos,
# Nearest to not: they,  often,  you,  also,  generally,  still,  it,  either,
# Nearest to one: two,  four,  six,  eight,  seven,  nine,  three,  five,
# Nearest to have: had,  has,  were,  be,  are,  mich,  properly,  trapezohedron,
# Nearest to are: were,  is,  have,  cycled,  be,  toba,  was,  being,
# Nearest to when: after,  where,  if,  as,  statuette,  tells,  mac,  pestilence,
# Nearest to be: been,  have,  englewood,  noncommercial,  become,  whittier,  are,  sulu,
# Nearest to people: taxi,  noirs,  wahhabis,  expressionism,  counterattacks,  refueling,  redesignated,  sequential,
# Nearest to b: jacky,  j,  asphyxia,  trojan,  beethoven,  distraught,  alpinus,  raster,
# Nearest to state: republic,  hilary,  flock,  gomoku,  bernardo,  university,  electra,  eastenders,
# Nearest to between: with,  dinar,  morales,  cypriot,  insertions,  dme,  eia,  worries,
# Nearest to had: has,  have,  was,  were,  sixths,  inductive,  anarchistic,  multi,
# Nearest to such: well,  known,  mallarm,  these,  different,  domestic,  banff,  silverstein,
# Average loss at step 22000: 1.000000
# Average loss at step 24000: 1.000000
# Average loss at step 26000: 1.000000
# Average loss at step 28000: 1.000000
# Average loss at step 30000: 1.000000
# Nearest to been: become,  be,  were,  was,  being,  crowell,  bingo,  ho,
# Nearest to nine: eight,  seven,  six,  five,  four,  zero,  three,  two,
# Nearest to d: vader,  unaccustomed,  nrc,  maps,  enslavement,  keiretsu,  trisha,  patrice,
# Nearest to known: used,  such,  siberia,  regarded,  well,  seen,  directing,  transnistrian,
# Nearest to not: you,  still,  often,  also,  they,  generally,  it,  mighty,
# Nearest to one: seven,  six,  eight,  two,  five,  four,  nine,  three,
# Nearest to have: had,  has,  were,  are,  be,  mich,  acetic,  trapezohedron,
# Nearest to are: were,  is,  have,  granular,  bronx,  include,  cycled,  nbs,
# Nearest to when: where,  after,  if,  before,  while,  by,  was,  statuette,
# Nearest to be: being,  been,  have,  was,  were,  englewood,  refer,  become,
# Nearest to people: counterattacks,  sequential,  critics,  redesignated,  wahhabis,  refueling,  taxi,  cases,
# Nearest to b: jacky,  n,  meath,  asphyxia,  j,  beethoven,  ave,  lullaby,
# Nearest to state: republic,  scottish,  ranch,  constrain,  spur,  housemate,  canton,  masterpieces,
# Nearest to between: with,  morales,  dinar,  dme,  from,  into,  cypriot,  insertions,
# Nearest to had: has,  have,  was,  were,  sixths,  virginity,  hormonal,  anarchistic,
# Nearest to such: these,  well,  known,  different,  mallarm,  many,  emanuel,  some,
# Average loss at step 32000: 1.000000
# Average loss at step 34000: 1.000000
# Average loss at step 36000: 1.000000
# Average loss at step 38000: 1.000000
# Average loss at step 40000: 1.000000
# Nearest to been: be,  become,  were,  was,  being,  had,  previously,  crowell,
# Nearest to nine: eight,  seven,  six,  five,  four,  zero,  three,  two,
# Nearest to d: vader,  unaccustomed,  enslavement,  trisha,  nrc,  maps,  unguarded,  shannon,
# Nearest to known: used,  such,  regarded,  well,  seen,  possible,  siberia,  refers,
# Nearest to not: still,  they,  it,  often,  athlon,  also,  never,  almost,
# Nearest to one: two,  seven,  eight,  three,  five,  six,  four,  nine,
# Nearest to have: had,  has,  were,  be,  having,  are,  ballads,  acetic,
# Nearest to are: were,  is,  include,  have,  although,  granular,  these,  cycled,
# Nearest to when: if,  after,  before,  where,  although,  while,  during,  since,
# Nearest to be: been,  have,  were,  being,  was,  become,  englewood,  refer,
# Nearest to people: men,  redesignated,  critics,  occasions,  wahhabis,  rebellions,  refueling,  fullerene,
# Nearest to b: c,  jacky,  j,  f,  meath,  asphyxia,  beethoven,  ave,
# Nearest to state: republic,  government,  states,  masterpieces,  hyderabad,  columbus,  choice,  scottish,
# Nearest to between: with,  morales,  into,  from,  in,  dinar,  insertions,  among,
# Nearest to had: has,  have,  were,  was,  having,  hannover,  hormonal,  virginity,
# Nearest to such: well,  these,  known,  regarded,  mallarm,  many,  thruster,  certain,
# Average loss at step 42000: 1.000000
# Average loss at step 44000: 1.000000
# Average loss at step 46000: 1.000000
# Average loss at step 48000: 1.000000
# Average loss at step 50000: 1.000000
# Nearest to been: become,  be,  was,  being,  were,  previously,  already,  traditionally,
# Nearest to nine: eight,  seven,  six,  four,  five,  three,  zero,  one,
# Nearest to d: b,  vader,  unaccustomed,  treasure,  lori,  butler,  tex,  patrice,
# Nearest to known: used,  such,  regarded,  well,  seen,  defined,  possible,  described,
# Nearest to not: generally,  still,  deemed,  athlon,  almost,  also,  dawson,  now,
# Nearest to one: two,  three,  four,  six,  seven,  five,  eight,  nine,
# Nearest to have: had,  has,  were,  be,  are,  having,  include,  contain,
# Nearest to are: were,  is,  be,  have,  include,  although,  these,  while,
# Nearest to when: if,  while,  after,  where,  before,  although,  during,  though,
# Nearest to be: been,  are,  have,  is,  being,  englewood,  were,  was,
# Nearest to people: men,  redesignated,  jews,  players,  others,  precocious,  minions,  critics,
# Nearest to b: j,  transduction,  d,  curtin,  c,  shimon,  kitt,  asphyxia,
# Nearest to state: masterpieces,  republic,  columbus,  government,  hyderabad,  states,  ranch,  cyborg,
# Nearest to between: with,  insertions,  cypriot,  morales,  into,  dme,  dinar,  among,
# Nearest to had: has,  have,  was,  were,  having,  would,  hannover,  hormonal,
# Nearest to such: well,  known,  these,  mallarm,  many,  regarded,  certain,  silverstein,
# Average loss at step 52000: 1.000000
# Average loss at step 54000: 1.000000
# Average loss at step 56000: 1.000000
# Average loss at step 58000: 1.000000
# Average loss at step 60000: 1.000000
# Nearest to been: become,  be,  was,  previously,  already,  being,  were,  had,
# Nearest to nine: eight,  seven,  six,  five,  four,  three,  zero,  two,
# Nearest to d: b,  vader,  treasure,  j,  lori,  transduction,  c,  mci,
# Nearest to known: used,  regarded,  seen,  possible,  defined,  such,  described,  written,
# Nearest to not: generally,  deemed,  still,  almost,  you,  either,  therefore,  calculated,
# Nearest to one: two,  seven,  three,  five,  six,  four,  nine,  eight,
# Nearest to have: had,  has,  were,  are,  be,  include,  having,  appear,
# Nearest to are: were,  have,  is,  including,  include,  those,  laconic,  although,
# Nearest to when: if,  where,  after,  while,  during,  although,  before,  though,
# Nearest to be: been,  have,  was,  being,  refer,  is,  become,  create,
# Nearest to people: men,  players,  minions,  children,  redesignated,  others,  critics,  jews,
# Nearest to b: d,  j,  transduction,  shimon,  kitt,  curtin,  vader,  c,
# Nearest to state: republic,  columbus,  government,  masterpieces,  states,  cyborg,  ducati,  college,
# Nearest to between: with,  dinar,  morales,  against,  among,  through,  cypriot,  insertions,
# Nearest to had: has,  have,  was,  were,  hannover,  having,  began,  hormonal,
# Nearest to such: well,  these,  known,  mallarm,  including,  many,  some,  prog,
# Average loss at step 62000: 1.000000
# Average loss at step 64000: 1.000000
# Average loss at step 66000: 1.000000
# Average loss at step 68000: 1.000000
# Average loss at step 70000: 1.000000
# Nearest to been: be,  become,  traditionally,  previously,  were,  was,  being,  prsc,
# Nearest to nine: eight,  six,  seven,  five,  four,  three,  zero,  two,
# Nearest to d: b,  vader,  l,  j,  n,  c,  mci,  lee,
# Nearest to known: used,  defined,  such,  seen,  possible,  regarded,  written,  famous,
# Nearest to not: generally,  therefore,  now,  usually,  still,  either,  deemed,  almost,
# Nearest to one: four,  two,  six,  five,  seven,  three,  nine,  eight,
# Nearest to have: had,  has,  be,  were,  having,  ballads,  are,  mich,
# Nearest to are: were,  is,  have,  be,  those,  although,  was,  include,
# Nearest to when: if,  while,  after,  before,  where,  although,  during,  though,
# Nearest to be: been,  have,  is,  become,  are,  create,  were,  refer,
# Nearest to people: men,  children,  redesignated,  women,  critics,  minions,  ideas,  ink,
# Nearest to b: d,  j,  c,  jacky,  g,  n,  f,  x,
# Nearest to state: columbus,  states,  masterpieces,  republic,  observation,  hyderabad,  proof,  ducati,
# Nearest to between: among,  with,  within,  in,  morales,  dinar,  through,  against,
# Nearest to had: has,  have,  was,  were,  hannover,  began,  refused,  having,
# Nearest to such: well,  these,  known,  mallarm,  certain,  including,  regarded,  prog,
# Average loss at step 72000: 1.000000
# Average loss at step 74000: 1.000000
# Average loss at step 76000: 1.000000
# Average loss at step 78000: 1.000000
# Average loss at step 80000: 1.000000
# Nearest to been: become,  be,  being,  were,  was,  traditionally,  had,  previously,
# Nearest to nine: eight,  seven,  six,  four,  five,  three,  zero,  two,
# Nearest to d: b,  vader,  l,  transduction,  treasure,  tramways,  ca,  scheduler,
# Nearest to known: used,  such,  possible,  defined,  seen,  regarded,  considered,  described,
# Nearest to not: now,  still,  either,  almost,  athlon,  actively,  generally,  deemed,
# Nearest to one: two,  seven,  four,  eight,  six,  five,  three,  inches,
# Nearest to have: had,  has,  are,  were,  having,  be,  ballads,  include,
# Nearest to are: were,  is,  have,  those,  include,  including,  laconic,  cycled,
# Nearest to when: if,  while,  where,  before,  although,  after,  during,  though,
# Nearest to be: been,  being,  have,  refer,  create,  were,  is,  become,
# Nearest to people: men,  redesignated,  children,  women,  minions,  those,  players,  critics,
# Nearest to b: d,  j,  jacky,  c,  g,  asphyxia,  p,  ave,
# Nearest to state: states,  republic,  masterpieces,  columbus,  wishbone,  government,  observation,  prat,
# Nearest to between: with,  among,  within,  from,  morales,  around,  insertions,  in,
# Nearest to had: has,  have,  was,  were,  having,  been,  hormonal,  virginity,
# Nearest to such: well,  these,  known,  mallarm,  regarded,  certain,  follows,  pasteur,
# Average loss at step 82000: 1.000000
# Average loss at step 84000: 1.000000
# Average loss at step 86000: 1.000000
# Average loss at step 88000: 1.000000
# Average loss at step 90000: 1.000000
# Nearest to been: become,  be,  previously,  traditionally,  was,  carnivorous,  were,  paranthropus,
# Nearest to nine: eight,  six,  seven,  five,  four,  three,  zero,  two,
# Nearest to d: b,  vader,  tramways,  testifies,  transduction,  allergy,  unguarded,  lori,
# Nearest to known: such,  used,  regarded,  possible,  defined,  seen,  described,  considered,
# Nearest to not: still,  never,  now,  actively,  either,  actually,  possibly,  deemed,
# Nearest to one: two,  seven,  five,  eight,  six,  four,  three,  nine,
# Nearest to have: had,  has,  be,  were,  include,  are,  having,  contain,
# Nearest to are: were,  is,  include,  those,  have,  these,  humiliating,  cycled,
# Nearest to when: if,  before,  while,  although,  after,  where,  though,  during,
# Nearest to be: been,  have,  become,  was,  is,  being,  whittier,  were,
# Nearest to people: men,  women,  children,  redesignated,  christians,  jews,  minions,  those,
# Nearest to b: d,  j,  rhinoceros,  transduction,  curtin,  jacky,  bangalore,  ave,
# Nearest to state: states,  government,  republic,  masterpieces,  indiana,  columbus,  prat,  wishbone,
# Nearest to between: with,  within,  among,  in,  morales,  from,  through,  around,
# Nearest to had: has,  have,  having,  were,  was,  hannover,  hormonal,  since,
# Nearest to such: known,  well,  these,  mallarm,  regarded,  philologist,  certain,  elapsed,
# Average loss at step 92000: 1.000000
# Average loss at step 94000: 1.000000
# Average loss at step 96000: 1.000000
# Average loss at step 98000: 1.000000
# Average loss at step 100000: 1.000000
# Nearest to been: become,  be,  were,  traditionally,  previously,  was,  being,  already,
# Nearest to nine: eight,  seven,  six,  five,  four,  three,  zero,  two,
# Nearest to d: b,  l,  c,  vader,  mci,  j,  unguarded,  allergy,
# Nearest to known: used,  possible,  regarded,  such,  defined,  seen,  described,  considered,
# Nearest to not: still,  never,  either,  now,  therefore,  actively,  actually,  generally,
# Nearest to one: two,  five,  seven,  three,  six,  eight,  four,  nine,
# Nearest to have: had,  has,  were,  are,  be,  include,  contain,  offer,
# Nearest to are: were,  is,  have,  include,  those,  devito,  roadmap,  laconic,
# Nearest to when: if,  before,  although,  while,  after,  though,  where,  during,
# Nearest to be: been,  have,  was,  were,  create,  become,  is,  being,
# Nearest to people: men,  women,  children,  critics,  redesignated,  christians,  ideas,  jews,
# Nearest to b: d,  j,  c,  jacky,  p,  f,  ave,  r,
# Nearest to state: states,  government,  republic,  indiana,  prat,  observation,  masterpieces,  columbus,
# Nearest to between: within,  with,  among,  cypriot,  in,  morales,  geometrical,  through,
# Nearest to had: has,  have,  was,  were,  having,  ballads,  hannover,  virginity,
# Nearest to such: known,  well,  these,  many,  mallarm,  elapsed,  follows,  certain,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-077cb5295fd2> in <module>()
#       1 num_points = 400
#       2 tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# ----> 3 two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
#
# /Users/user/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/user/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/user/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     845         opt_args['it'] = it + 1
#     846         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 847                                                       **opt_args)
#     848         if self.verbose:
#     849             print("[t-SNE] KL divergence after %d iterations with early "
#
# /Users/user/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/user/anaconda/lib/python2.7/site-packages/scipy/linalg/misc.pyc in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/user/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15)) # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5,2), textcoords='offset points',
                      ha = 'right', va='bottom')
    pylab.show()
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f289ec9847d8> in <module>()
#       9     pylab.show()
#      10 words = [reverse_dictionary[i] for i in range(1, num_points+1)]
# ---> 11 plot(two_d_embeddings, words)
#
# NameError: name 'two_d_embeddings' is not defined
