# %%
# These are ll the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
# %config InlineBackend.close_figures = False
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'
def maybe_download(filename, expected_bytes):
    """Dowload a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename +
                       '. Can you get it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as as list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0 # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])
for num_skips, skip_window in [(2,1), (2,2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels ['anarchism', 'term', 'of', 'term', 'abuse', 'a', 'first', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right
num_skips = 2 # How many times to reuse an input to generate a label
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    # Look up embeddings for inputs
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                    labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` methods will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += 1
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s, ' % (log, close_word)
                print(log)
final_embeddings = normalized_embeddings.eval()

# 이거 한글도 적용해보장
# Out:
# Initialized
# Average loss at step 0: 1.000000
# Nearest to some: pies,  coslet,  homosexuals,  cub,  dogmatic,  elysium,  explores,  muggles,
# Nearest to states: wireless,  rowdy,  day,  autocrat,  shechem,  dramatised,  iqaluit,  humiliating,
# Nearest to seven: isi,  losses,  merci,  purr,  prelude,  available,  broadcasters,  bucket,
# Nearest to can: qasim,  ibu,  ramanujan,  gallipoli,  dalglish,  ietf,  valhalla,  neo,
# Nearest to an: regum,  hapless,  coastal,  reconsider,  sighted,  powerplant,  black,  nowak,
# Nearest to had: mcmanus,  chileans,  blaxploitation,  montoya,  intoxication,  gibraltar,  thermionic,  oni,
# Nearest to its: ashmore,  westerns,  algae,  ep,  odegard,  hilberg,  estonia,  wept,
# Nearest to will: doubtful,  larnaca,  timed,  rastafari,  cali,  stab,  beginner,  subterranean,
# Nearest to during: introductions,  onion,  cadbury,  licensing,  assigning,  kale,  sza,  excise,
# Nearest to four: indoors,  jumo,  harrow,  ker,  beheading,  deprivation,  reminiscent,  esperanto,
# Nearest to to: satellites,  gmbh,  replaces,  recognize,  slows,  ue,  diner,  plagues,
# Nearest to are: gabriele,  tasking,  zork,  exclave,  berets,  australes,  identically,  relinquish,
# Nearest to use: expands,  mansion,  dons,  branwell,  vestal,  interlaced,  jessie,  controllers,
# Nearest to united: miata,  shamans,  rolled,  stature,  insisted,  dwell,  blurry,  turpin,
# Nearest to with: photosynthesis,  circumnavigate,  pioneering,  singles,  residence,  lubbock,  tempering,  corruptions,
# Nearest to d: folketing,  janata,  karachi,  maitreya,  deshima,  commemoration,  storey,  ibelin,
# Average loss at step 2000: 1.000000
# Average loss at step 4000: 1.000000
# Average loss at step 6000: 1.000000
# Average loss at step 8000: 1.000000
# Average loss at step 10000: 1.000000
# Nearest to some: many,  decisively,  cub,  dogmatic,  all,  ec,  consolidating,  stern,
# Nearest to states: day,  humiliating,  wireless,  schwenkfeld,  england,  autocrat,  yuan,  immunosuppression,
# Nearest to seven: six,  eight,  five,  nine,  four,  three,  zero,  two,
# Nearest to can: may,  would,  monarch,  qasim,  accordingly,  pitts,  valhalla,  crtc,
# Nearest to an: the,  queues,  regum,  faraday,  wma,  nowak,  kabul,  it,
# Nearest to had: has,  was,  have,  thermionic,  been,  snoop,  ambulances,  montoya,
# Nearest to its: their,  the,  westerns,  his,  this,  herding,  compilation,  warr,
# Nearest to will: stab,  carotenoids,  doubtful,  may,  can,  prompt,  must,  arrival,
# Nearest to during: onion,  excise,  debbie,  sdram,  argumentation,  screens,  katha,  noxious,
# Nearest to four: six,  three,  five,  seven,  eight,  two,  nine,  zero,
# Nearest to to: ue,  sucre,  chickens,  gibbs,  would,  not,  sven,  cannot,
# Nearest to are: were,  is,  have,  lingerie,  dipped,  wharf,  vestry,  charging,
# Nearest to use: expands,  jessie,  dons,  mansion,  elaborating,  pelagius,  vestal,  branwell,
# Nearest to united: miata,  hksar,  shabda,  blackjack,  emblematic,  shamans,  cezanne,  second,
# Nearest to with: in,  obliterated,  carnap,  by,  spaced,  saves,  peacekeepers,  towards,
# Nearest to d: b,  maitreya,  bogside,  mutagens,  matsushita,  telemetry,  damian,  dissociated,
# Average loss at step 12000: 1.000000
# Average loss at step 14000: 1.000000
# Average loss at step 16000: 1.000000
# Average loss at step 18000: 1.000000
# Average loss at step 20000: 1.000000
# Nearest to some: many,  these,  several,  all,  most,  other,  their,  his,
# Nearest to states: humiliating,  england,  underscore,  schwenkfeld,  day,  gs,  compilation,  wireless,
# Nearest to seven: eight,  six,  five,  three,  four,  nine,  zero,  two,
# Nearest to can: may,  would,  will,  could,  should,  pitts,  accordingly,  monarch,
# Nearest to an: faraday,  queues,  strings,  rapport,  the,  wma,  coastal,  russcol,
# Nearest to had: has,  have,  was,  were,  bodily,  having,  sprays,  ambulances,
# Nearest to its: their,  his,  the,  her,  this,  supernaturally,  foreskin,  affection,
# Nearest to will: can,  may,  would,  must,  stab,  carotenoids,  should,  could,
# Nearest to during: sdram,  onion,  screens,  excise,  debbie,  argumentation,  in,  when,
# Nearest to four: six,  eight,  three,  seven,  five,  nine,  two,  zero,
# Nearest to to: sucre,  would,  could,  ue,  cannot,  not,  gibbs,  can,
# Nearest to are: were,  is,  have,  wharf,  vestry,  was,  equalized,  but,
# Nearest to use: dons,  jessie,  expands,  addresses,  antimatter,  mansion,  elaborating,  vestal,
# Nearest to united: miata,  shabda,  southern,  hksar,  waka,  shamans,  entire,  warlord,
# Nearest to with: aleksei,  in,  empiricist,  carnap,  by,  supervisory,  unfilled,  hyperfocal,
# Nearest to d: b,  maitreya,  telemetry,  german,  dtd,  methionine,  balaguer,  minigun,
# Average loss at step 22000: 1.000000
# Average loss at step 24000: 1.000000
# Average loss at step 26000: 1.000000
# Average loss at step 28000: 1.000000
# Average loss at step 30000: 1.000000
# Nearest to some: many,  these,  several,  all,  most,  those,  other,  their,
# Nearest to states: underscore,  nbs,  england,  yuan,  etruscans,  feet,  nations,  kn,
# Nearest to seven: five,  six,  eight,  nine,  four,  three,  zero,  two,
# Nearest to can: may,  would,  will,  could,  should,  must,  might,  pitts,
# Nearest to an: strings,  wma,  nowak,  faraday,  queues,  regum,  plutonium,  lambda,
# Nearest to had: have,  has,  were,  was,  says,  been,  leak,  bodily,
# Nearest to its: their,  the,  his,  her,  supernaturally,  westerns,  implant,  each,
# Nearest to will: can,  would,  may,  must,  could,  should,  to,  regan,
# Nearest to during: after,  in,  onion,  through,  sdram,  anglophone,  screens,  until,
# Nearest to four: five,  eight,  three,  six,  seven,  nine,  two,  zero,
# Nearest to to: sucre,  would,  can,  will,  cannot,  ue,  could,  heterozygote,
# Nearest to are: were,  have,  is,  include,  these,  equalized,  be,  although,
# Nearest to use: dons,  jessie,  mansion,  expands,  sundial,  pelagius,  elaborating,  niger,
# Nearest to united: miata,  southern,  shabda,  waka,  shamans,  holocaust,  supreme,  bancroft,
# Nearest to with: between,  in,  by,  aleksei,  hyperfocal,  under,  valencian,  carnap,
# Nearest to d: b,  maitreya,  telemetry,  minigun,  dtd,  mutagens,  spahn,  qua,
# Average loss at step 32000: 1.000000
# Average loss at step 34000: 1.000000
# Average loss at step 36000: 1.000000
# Average loss at step 38000: 1.000000
# Average loss at step 40000: 1.000000
# Nearest to some: many,  these,  several,  those,  any,  certain,  their,  most,
# Nearest to states: underscore,  kingdom,  nations,  nbs,  yuan,  england,  feet,  cpu,
# Nearest to seven: eight,  six,  nine,  five,  four,  three,  zero,  two,
# Nearest to can: may,  would,  will,  could,  must,  should,  might,  shall,
# Nearest to an: queues,  wma,  faraday,  nowak,  fijian,  polytechnique,  brasil,  implants,
# Nearest to had: has,  have,  was,  were,  says,  having,  tirpitz,  sponsored,
# Nearest to its: their,  his,  the,  her,  westerns,  babur,  thatched,  gotthold,
# Nearest to will: can,  would,  may,  could,  must,  should,  to,  regan,
# Nearest to during: after,  since,  before,  until,  in,  against,  sdram,  at,
# Nearest to four: six,  five,  seven,  three,  eight,  two,  nine,  one,
# Nearest to to: will,  sucre,  cannot,  could,  ue,  must,  should,  may,
# Nearest to are: were,  have,  include,  is,  be,  equalized,  these,  being,
# Nearest to use: spake,  jessie,  antimatter,  vastly,  pelagius,  elaborating,  available,  lack,
# Nearest to united: miata,  supreme,  waka,  shabda,  holocaust,  medlineplus,  shamans,  southern,
# Nearest to with: by,  carnap,  between,  spaced,  peacekeepers,  hyperfocal,  in,  aleksei,
# Nearest to d: b,  maitreya,  mutagens,  telemetry,  minigun,  dtd,  spahn,  miskelley,
# Average loss at step 42000: 1.000000
# Average loss at step 44000: 1.000000
# Average loss at step 46000: 1.000000
# Average loss at step 48000: 1.000000
# Average loss at step 50000: 1.000000
# Nearest to some: many,  these,  several,  various,  those,  both,  all,  most,
# Nearest to states: kingdom,  nations,  underscore,  nbs,  ios,  state,  revision,  england,
# Nearest to seven: eight,  six,  four,  nine,  five,  three,  zero,  two,
# Nearest to can: may,  would,  could,  will,  must,  should,  might,  cannot,
# Nearest to an: queues,  nowak,  faraday,  implants,  the,  wma,  this,  plutonium,
# Nearest to had: has,  have,  was,  having,  were,  says,  positives,  leak,
# Nearest to its: their,  his,  the,  her,  gotthold,  babur,  supernaturally,  faces,
# Nearest to will: would,  can,  could,  may,  must,  should,  does,  shall,
# Nearest to during: after,  when,  in,  before,  at,  anglophone,  against,  since,
# Nearest to four: six,  seven,  five,  eight,  three,  nine,  two,  zero,
# Nearest to to: sucre,  would,  ue,  could,  dizziness,  informers,  will,  sven,
# Nearest to are: were,  is,  have,  include,  be,  equalized,  those,  tombstone,
# Nearest to use: sense,  lack,  eighteen,  vastly,  unaided,  elaborating,  using,  treatment,
# Nearest to united: miata,  southern,  waka,  supreme,  shabda,  cezanne,  medlineplus,  conquest,
# Nearest to with: between,  spaced,  by,  communions,  catered,  aleksei,  hyperfocal,  illustrating,
# Nearest to d: b,  mutagens,  maitreya,  e,  nh,  dtd,  minigun,  matsushita,
# Average loss at step 52000: 1.000000
# Average loss at step 54000: 1.000000
# Average loss at step 56000: 1.000000
# Average loss at step 58000: 1.000000
# Average loss at step 60000: 1.000000
# Nearest to some: many,  several,  these,  all,  those,  various,  any,  most,
# Nearest to states: kingdom,  nations,  countries,  nbs,  underscore,  ios,  state,  tilsit,
# Nearest to seven: eight,  six,  nine,  four,  five,  zero,  three,  two,
# Nearest to can: may,  could,  would,  must,  will,  should,  might,  cannot,
# Nearest to an: nowak,  queues,  spotty,  wma,  faraday,  fijian,  regum,  implants,
# Nearest to had: has,  have,  was,  were,  having,  says,  been,  claimed,
# Nearest to its: their,  his,  her,  the,  your,  gotthold,  our,  westerns,
# Nearest to will: would,  could,  may,  can,  must,  should,  shall,  does,
# Nearest to during: after,  in,  before,  since,  following,  when,  until,  anglophone,
# Nearest to four: six,  five,  three,  eight,  seven,  nine,  two,  zero,
# Nearest to to: sucre,  would,  ue,  will,  cannot,  may,  only,  must,
# Nearest to are: were,  is,  have,  include,  including,  although,  bailiwick,  subgenus,
# Nearest to use: sense,  eighteen,  unaided,  way,  cover,  antimatter,  spake,  lack,
# Nearest to united: miata,  supreme,  cezanne,  southern,  waka,  senate,  warlord,  coolest,
# Nearest to with: between,  spaced,  sns,  by,  including,  hyperfocal,  when,  in,
# Nearest to d: b,  mutagens,  maitreya,  ibelin,  sse,  matsushita,  nh,  minigun,
# Average loss at step 62000: 1.000000
# Average loss at step 64000: 1.000000
# Average loss at step 66000: 1.000000
# Average loss at step 68000: 1.000000
# Average loss at step 70000: 1.000000
# Nearest to some: many,  several,  these,  all,  various,  most,  those,  any,
# Nearest to states: kingdom,  nations,  state,  countries,  nbs,  underscore,  ios,  tilsit,
# Nearest to seven: six,  eight,  nine,  five,  four,  three,  zero,  two,
# Nearest to can: may,  could,  would,  must,  will,  should,  might,  cannot,
# Nearest to an: nowak,  queues,  faraday,  implants,  devas,  microwaves,  prevalence,  spotty,
# Nearest to had: have,  has,  was,  were,  having,  says,  been,  claimed,
# Nearest to its: their,  his,  her,  the,  your,  our,  westerns,  babur,
# Nearest to will: would,  could,  may,  can,  must,  should,  shall,  might,
# Nearest to during: after,  before,  in,  since,  until,  despite,  throughout,  when,
# Nearest to four: six,  five,  eight,  seven,  three,  zero,  nine,  two,
# Nearest to to: would,  ue,  will,  sucre,  must,  could,  cannot,  for,
# Nearest to are: were,  is,  have,  include,  including,  although,  tombstone,  these,
# Nearest to use: copy,  lack,  sense,  tracked,  unaided,  using,  cover,  eighteen,
# Nearest to united: supreme,  miata,  cezanne,  waka,  neighbouring,  warlord,  glee,  southern,
# Nearest to with: between,  spaced,  peacekeepers,  without,  carnap,  hyperfocal,  ssl,  publicised,
# Nearest to d: b,  maitreya,  mutagens,  sse,  nh,  ocogs,  di,  matsushita,
# Average loss at step 72000: 1.000000
# Average loss at step 74000: 1.000000
# Average loss at step 76000: 1.000000
# Average loss at step 78000: 1.000000
# Average loss at step 80000: 1.000000
# Nearest to some: many,  several,  these,  various,  most,  certain,  doings,  any,
# Nearest to states: kingdom,  nations,  us,  nbs,  countries,  state,  ios,  casinos,
# Nearest to seven: six,  eight,  five,  four,  three,  nine,  zero,  one,
# Nearest to can: could,  may,  will,  would,  must,  should,  cannot,  might,
# Nearest to an: nowak,  prevalence,  successfully,  queues,  wma,  implants,  gchq,  microwaves,
# Nearest to had: has,  have,  were,  was,  having,  been,  are,  never,
# Nearest to its: their,  his,  her,  your,  the,  our,  westerns,  gotthold,
# Nearest to will: would,  could,  can,  may,  must,  should,  might,  cannot,
# Nearest to during: after,  before,  when,  in,  despite,  following,  since,  although,
# Nearest to four: five,  six,  eight,  seven,  three,  nine,  two,  zero,
# Nearest to to: will,  sucre,  cannot,  ue,  would,  diner,  should,  workloads,
# Nearest to are: were,  have,  include,  is,  although,  equalized,  these,  had,
# Nearest to use: lack,  unaided,  sundial,  retain,  eighteen,  way,  copy,  acquires,
# Nearest to united: supreme,  miata,  cezanne,  warlord,  waka,  glee,  golf,  beacon,
# Nearest to with: between,  spaced,  on,  by,  in,  when,  illustrating,  aleksei,
# Nearest to d: b,  p,  maitreya,  mutagens,  di,  matsushita,  sentimental,  ablaut,
# Average loss at step 82000: 1.000000
# Average loss at step 84000: 1.000000
# Average loss at step 86000: 1.000000
# Average loss at step 88000: 1.000000
# Average loss at step 90000: 1.000000
# Nearest to some: many,  several,  these,  most,  any,  both,  all,  certain,
# Nearest to states: nations,  kingdom,  us,  countries,  nbs,  dish,  state,  slidell,
# Nearest to seven: five,  eight,  six,  four,  nine,  three,  one,  zero,
# Nearest to can: could,  may,  must,  would,  will,  should,  might,  cannot,
# Nearest to an: nowak,  successfully,  queues,  deansgate,  brasil,  wma,  fijian,  implants,
# Nearest to had: has,  have,  was,  were,  having,  continued,  earnest,  since,
# Nearest to its: their,  his,  her,  your,  the,  our,  babur,  westerns,
# Nearest to will: would,  could,  can,  must,  may,  should,  might,  shall,
# Nearest to during: after,  in,  before,  although,  when,  at,  while,  despite,
# Nearest to four: seven,  five,  three,  six,  eight,  two,  nine,  one,
# Nearest to to: sucre,  ue,  towards,  would,  informers,  heterozygote,  joins,  will,
# Nearest to are: were,  is,  include,  have,  these,  although,  equalized,  tombstone,
# Nearest to use: lack,  treatment,  eighteen,  restricts,  adopt,  retain,  way,  most,
# Nearest to united: supreme,  miata,  warlord,  waka,  constitution,  cezanne,  cumberland,  southern,
# Nearest to with: between,  spaced,  in,  by,  communions,  unfairly,  elucidated,  aerials,
# Nearest to d: b,  maitreya,  ablaut,  sentimental,  nd,  kwh,  barry,  homeworld,
# Average loss at step 92000: 1.000000
# Average loss at step 94000: 1.000000
# Average loss at step 96000: 1.000000
# Average loss at step 98000: 1.000000
# Average loss at step 100000: 1.000000
# Nearest to some: many,  several,  any,  these,  certain,  various,  lunatics,  their,
# Nearest to states: nations,  kingdom,  us,  nbs,  state,  countries,  slidell,  dish,
# Nearest to seven: six,  eight,  four,  five,  nine,  three,  two,  zero,
# Nearest to can: may,  could,  must,  will,  would,  should,  cannot,  might,
# Nearest to an: queues,  nowak,  deansgate,  another,  devas,  successfully,  logician,  gchq,
# Nearest to had: has,  have,  was,  having,  were,  is,  since,  tir,
# Nearest to its: their,  his,  the,  her,  your,  our,  westerns,  babur,
# Nearest to will: would,  could,  can,  must,  may,  should,  might,  cannot,
# Nearest to during: after,  in,  following,  before,  throughout,  when,  despite,  although,
# Nearest to four: seven,  five,  six,  eight,  three,  nine,  two,  zero,
# Nearest to to: will,  should,  sucre,  could,  must,  would,  can,  cannot,
# Nearest to are: were,  have,  include,  although,  is,  these,  equalized,  including,
# Nearest to use: retain,  lack,  tracked,  restricts,  sense,  way,  taxpayers,  adopt,
# Nearest to united: miata,  supreme,  constitution,  warlord,  senate,  cumberland,  southern,  waka,
# Nearest to with: between,  including,  spaced,  peacekeepers,  in,  fedayeen,  gypsys,  communions,
# Nearest to d: b,  maitreya,  homeworld,  patriarchy,  gahan,  mutagens,  telemetry,  ablaut,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-fbddb78e0650> in <module>()
#      27                     log = '%s %s, ' % (log, close_word)
#      28                 print(log)
# ---> 29 final_embeddings = normalized_embeddings.eval()
#      30
#      31 # 이거 한글도 적용해보장
#
# /Users/user/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in eval(self, feed_dict, session)
#     579
#     580     """
# --> 581     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     582
#     583
#
# /Users/user/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3781     session = get_default_session()
#    3782     if session is None:
# -> 3783       raise ValueError("Cannot evaluate tensor using `eval()`: No default "
#    3784                        "session is registered. Use `with "
#    3785                        "sess.as_default()` or pass an explicit session to "
#
# ValueError: Cannot evaluate tensor using `eval()`: No default session is registered. Use `with sess.as_default()` or pass an explicit session to `eval(session=sess)`

# %%
arr = np.array([1,2,3,4,5])
-arr
# Out:
# array([-1, -2, -3, -4, -5])
