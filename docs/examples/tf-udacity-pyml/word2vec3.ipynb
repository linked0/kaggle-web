# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'originated', 'of', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
print('processing end')
# Out:
# Initialized
# Average loss at step 0: 7.938998
# Nearest to b: auctioned, argus, strident, appearing, degrees, intellectualism, reincorporated, usher,
# Nearest to so: dealings, templars, bumblebee, grunt, actinide, ryu, kazantzakis, transit,
# Nearest to while: pataki, newfound, gotlanders, searle, dialogues, alien, redneck, overcrowded,
# Nearest to has: turtledove, females, riaa, doesburg, fletcher, castrated, jet, sms,
# Nearest to more: trafford, interact, converter, merodach, shortfalls, witbrock, aliens, completed,
# Nearest to time: judi, jettisoned, anesthetics, batavian, partaking, drunkenness, swelling, goalkeepers,
# Nearest to be: landing, formulations, suppress, ivo, vx, supervising, sanctify, popularize,
# Nearest to however: internationalist, translators, leftism, oiled, hanna, elysium, bonanza, statistician,
# Nearest to no: fink, horned, biham, lauren, counsels, catharism, laptop, millennial,
# Nearest to between: topology, elliptic, raza, hines, cremona, gpl, lads, zoster,
# Nearest to that: communes, erhard, prewar, embodiment, commuting, ulf, antagonist, molino,
# Nearest to by: indebtedness, hobbit, sniper, kevlar, rid, indymedia, untitled, abstention,
# Nearest to he: regression, chasing, beatification, rapport, adapter, summon, blotting, sheila,
# Nearest to this: depopulation, atlantic, clears, trait, infallible, paleontology, xena, sinai,
# Nearest to if: forefront, piraeus, scottie, abalone, robo, mo, consilience, vajrayana,
# Nearest to three: noam, aves, enumerates, iturbide, caesium, dropouts, opel, normalize,
# Average loss at step 2000: 4.368440
# Average loss at step 4000: 3.869174
# Average loss at step 6000: 3.785125
# Average loss at step 8000: 3.684103
# Average loss at step 10000: 3.614662
# Nearest to b: argus, venice, d, missed, jules, def, flew, adowa,
# Nearest to so: grunt, chimp, intelligibility, ephemerides, she, templars, gory, presocratic,
# Nearest to while: pataki, redneck, country, hopped, alioth, gotlanders, imaginative, earthly,
# Nearest to has: had, have, is, was, expositions, rgb, doesburg, females,
# Nearest to more: trafford, interact, yakko, folketing, monotonous, vanishes, novorossiysk, reproach,
# Nearest to time: bassists, jettisoned, anesthetics, judi, refrigerants, golda, valdez, flamboyant,
# Nearest to be: have, ivo, atop, by, refer, landing, hollandic, been,
# Nearest to however: but, puppet, analogous, limestone, internationalist, aka, hard, chechen,
# Nearest to no: counsels, horned, laptop, skye, tavistock, biham, rutskoy, lauren,
# Nearest to between: topology, elliptic, hines, with, dread, drang, catheter, of,
# Nearest to that: which, what, this, modem, starring, rigour, accreditation, photovoltaic,
# Nearest to by: with, peck, was, be, after, from, brandeis, as,
# Nearest to he: it, they, she, who, there, aryabhata, messy, lieben,
# Nearest to this: the, it, which, that, gill, salvadorans, endogenous, fermionic,
# Nearest to if: piraeus, microorganism, footballer, abalone, verso, deranged, mo, emotive,
# Nearest to three: five, four, eight, six, seven, two, nine, zero,
# Average loss at step 12000: 3.603897
# Average loss at step 14000: 3.569783
# Average loss at step 16000: 3.407730
# Average loss at step 18000: 3.453355
# Average loss at step 20000: 3.538019
# Nearest to b: d, venice, tabular, bengali, missed, oaxaca, argus, aboard,
# Nearest to so: grunt, haploid, mindfulness, she, presocratic, predominance, ephemerides, lumberjack,
# Nearest to while: pataki, alioth, following, but, artur, refrigerators, alien, however,
# Nearest to has: had, have, was, is, enduring, remained, expositions, encroached,
# Nearest to more: less, most, reproach, trafford, yakko, interact, folketing, nt,
# Nearest to time: year, bassists, swastika, staged, anesthetics, ground, envy, flamboyant,
# Nearest to be: have, is, been, refer, by, was, ivo, atop,
# Nearest to however: but, though, there, too, that, festivities, puppet, analogous,
# Nearest to no: skye, immunology, counsels, spirals, rutskoy, any, laptop, tavistock,
# Nearest to between: topology, with, dread, from, raza, hines, drang, elliptic,
# Nearest to that: which, what, starring, rigour, fragile, however, muonium, this,
# Nearest to by: with, were, after, be, was, been, is, greatly,
# Nearest to he: it, she, they, who, there, dysprosium, also, nh,
# Nearest to this: it, which, the, salvadorans, any, another, his, westward,
# Nearest to if: microorganism, when, but, deranged, do, cognates, though, because,
# Nearest to three: four, five, two, six, seven, eight, one, zero,
# Average loss at step 22000: 3.502665
# Average loss at step 24000: 3.492308
# Average loss at step 26000: 3.482357
# Average loss at step 28000: 3.477757
# Average loss at step 30000: 3.502699
# Nearest to b: d, tabular, oaxaca, osz, j, missed, independant, bengali,
# Nearest to so: grunt, haploid, mindfulness, gory, zhuang, predominance, projekt, erupt,
# Nearest to while: when, are, but, however, although, alioth, pataki, is,
# Nearest to has: had, have, is, was, remained, initialized, enduring, contains,
# Nearest to more: less, most, very, reproach, folketing, rather, roi, nt,
# Nearest to time: bassists, year, esse, staged, ground, wrappings, swastika, caitlin,
# Nearest to be: have, refer, been, is, was, ivo, were, are,
# Nearest to however: but, though, although, that, there, and, too, while,
# Nearest to no: any, skye, always, immunology, counsels, pneumonic, laptop, eads,
# Nearest to between: with, topology, dread, raza, in, from, against, over,
# Nearest to that: which, what, however, this, muonium, starring, censorware, austerity,
# Nearest to by: in, under, after, with, from, was, as, were,
# Nearest to he: she, it, they, who, there, dysprosium, lieben, landry,
# Nearest to this: it, which, that, sailing, what, troubling, another, not,
# Nearest to if: when, but, though, because, microorganism, however, where, network,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Average loss at step 32000: 3.501191
# Average loss at step 34000: 3.492931
# Average loss at step 36000: 3.457241
# Average loss at step 38000: 3.299802
# Average loss at step 40000: 3.432111
# Nearest to b: d, UNK, j, c, tabular, politburo, salazar, herbert,
# Nearest to so: haploid, grunt, erupt, zhuang, mindfulness, predominance, projekt, accidental,
# Nearest to while: when, although, were, but, was, are, where, however,
# Nearest to has: had, have, was, is, initialized, remained, skyscrapers, enduring,
# Nearest to more: less, most, rather, very, reproach, better, greater, takers,
# Nearest to time: year, day, bassists, period, ground, golda, wrappings, caitlin,
# Nearest to be: refer, been, have, ivo, by, togo, is, were,
# Nearest to however: but, though, although, that, too, while, it, moniker,
# Nearest to no: any, skye, immunology, statistics, always, still, counsels, bull,
# Nearest to between: with, topology, over, raza, from, dread, against, dvorak,
# Nearest to that: which, what, this, however, rapidly, herse, there, then,
# Nearest to by: be, was, peck, from, hexafluoride, with, romanians, inquisition,
# Nearest to he: she, it, they, who, there, dysprosium, i, lieben,
# Nearest to this: which, it, the, that, any, some, another, he,
# Nearest to if: when, where, though, verso, because, microorganism, presupposition, vajrayana,
# Nearest to three: two, four, seven, five, six, eight, nine, zero,
# Average loss at step 42000: 3.432988
# Average loss at step 44000: 3.457385
# Average loss at step 46000: 3.446665
# Average loss at step 48000: 3.349981
# Average loss at step 50000: 3.382341
# Nearest to b: d, r, c, j, zionists, x, herbert, politburo,
# Nearest to so: haploid, erupt, however, accidental, olfactory, then, nocs, gory,
# Nearest to while: although, when, after, however, before, but, if, against,
# Nearest to has: had, have, was, is, contains, skyscrapers, arrogance, knee,
# Nearest to more: less, most, very, extremely, rather, commentarii, haworth, greater,
# Nearest to time: year, week, period, day, golda, contest, way, rcaf,
# Nearest to be: have, refer, been, was, being, ivo, is, were,
# Nearest to however: but, although, though, that, while, so, revoluci, where,
# Nearest to no: any, skye, always, little, a, undergoing, bull, another,
# Nearest to between: with, topology, against, dread, raza, communicated, over, duplicates,
# Nearest to that: which, however, what, this, generally, but, werth, who,
# Nearest to by: through, under, euthanasia, during, magadha, pedestrians, paradox, was,
# Nearest to he: she, it, they, there, who, dysprosium, this, deccan,
# Nearest to this: which, it, the, some, there, he, that, any,
# Nearest to if: when, although, though, where, while, microorganism, verso, presupposition,
# Nearest to three: four, six, seven, two, five, eight, nine, one,
# Average loss at step 52000: 3.437891
# Average loss at step 54000: 3.428129
# Average loss at step 56000: 3.437178
# Average loss at step 58000: 3.395316
# Average loss at step 60000: 3.393445
# Nearest to b: d, r, c, j, p, aboard, politburo, y,
# Nearest to so: haploid, erupt, zhuang, accidental, mindfulness, olfactory, presocratic, gory,
# Nearest to while: although, when, after, before, though, sustaining, however, were,
# Nearest to has: had, have, is, was, spee, contains, nibelungenlied, inferences,
# Nearest to more: less, most, very, rather, extremely, greater, commentarii, increasingly,
# Nearest to time: week, year, period, number, day, round, scriptwriter, golda,
# Nearest to be: been, refer, have, ivo, precedence, was, is, remain,
# Nearest to however: but, although, though, that, which, ethelbert, when, while,
# Nearest to no: any, skye, little, digweed, holland, amusing, nanaimo, a,
# Nearest to between: with, topology, over, in, among, against, raza, communicated,
# Nearest to that: which, however, what, this, often, there, censorware, who,
# Nearest to by: through, under, wyatt, with, specially, domitian, ecosystems, as,
# Nearest to he: she, it, they, dysprosium, there, who, never, greenpeace,
# Nearest to this: it, which, there, that, some, the, westward, however,
# Nearest to if: when, where, though, for, although, presupposition, but, whether,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Average loss at step 62000: 3.244516
# Average loss at step 64000: 3.255214
# Average loss at step 66000: 3.405926
# Average loss at step 68000: 3.394717
# Average loss at step 70000: 3.358012
# Nearest to b: d, r, j, f, n, y, p, c,
# Nearest to so: erupt, zhuang, haploid, accidental, mineralogical, nocs, gory, however,
# Nearest to while: although, when, however, before, after, though, if, unlike,
# Nearest to has: had, have, was, is, contains, since, does, unaccompanied,
# Nearest to more: less, most, very, rather, extremely, increasingly, commentarii, higher,
# Nearest to time: week, period, round, year, sense, however, happened, bassists,
# Nearest to be: been, is, was, were, being, refer, remain, are,
# Nearest to however: but, although, though, while, that, where, when, ethelbert,
# Nearest to no: any, skye, little, always, dunwich, there, laptop, amusing,
# Nearest to between: with, topology, among, within, in, from, raza, communicated,
# Nearest to that: which, what, however, this, usually, but, often, generally,
# Nearest to by: through, fanciful, using, lonsdaleite, warns, wyatt, rene, be,
# Nearest to he: she, it, they, dysprosium, there, who, greenpeace, we,
# Nearest to this: it, which, the, that, another, some, there, crescas,
# Nearest to if: when, though, where, while, although, before, vajrayana, however,
# Nearest to three: four, six, two, five, seven, eight, nine, one,
# Average loss at step 72000: 3.375869
# Average loss at step 74000: 3.349800
# Average loss at step 76000: 3.319117
# Average loss at step 78000: 3.349222
# Average loss at step 80000: 3.378907
# Nearest to b: d, r, c, j, p, y, zionists, x,
# Nearest to so: zhuang, erupt, haploid, nocs, accidental, mineralogical, mindfulness, something,
# Nearest to while: although, when, after, though, however, before, if, or,
# Nearest to has: had, have, is, was, although, since, inferences, having,
# Nearest to more: less, very, most, rather, extremely, greater, offsets, haworth,
# Nearest to time: week, year, round, success, karabakh, day, period, sense,
# Nearest to be: been, have, refer, become, being, is, easily, ivo,
# Nearest to however: although, but, though, that, while, ethelbert, where, like,
# Nearest to no: little, skye, dunwich, any, nothing, always, eads, digweed,
# Nearest to between: with, among, within, over, dread, in, tx, raza,
# Nearest to that: which, however, what, censorware, modem, this, taverns, where,
# Nearest to by: through, from, alexandros, euthanasia, under, catolica, peck, fanciful,
# Nearest to he: she, it, they, there, who, dysprosium, we, hb,
# Nearest to this: it, which, the, another, that, crescas, there, he,
# Nearest to if: when, though, where, before, while, presupposition, although, since,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Average loss at step 82000: 3.408355
# Average loss at step 84000: 3.408172
# Average loss at step 86000: 3.392229
# Average loss at step 88000: 3.353263
# Average loss at step 90000: 3.367012
# Nearest to b: d, j, r, f, c, y, n, zero,
# Nearest to so: zhuang, haploid, erupt, nocs, mineralogical, accidental, presocratic, too,
# Nearest to while: although, when, after, though, before, were, during, unlike,
# Nearest to has: had, have, is, was, having, contains, since, includes,
# Nearest to more: less, very, most, rather, greater, extremely, increasingly, offsets,
# Nearest to time: week, year, shouldn, success, reason, euclidean, sort, bassists,
# Nearest to be: been, refer, become, have, is, was, easily, being,
# Nearest to however: but, although, though, that, since, while, opens, ethelbert,
# Nearest to no: little, any, skye, nothing, always, there, only, bmc,
# Nearest to between: with, within, among, tx, in, raza, from, scholarships,
# Nearest to that: which, however, what, aldosterone, herse, but, austerity, raves,
# Nearest to by: through, alexandros, under, without, warns, when, wyatt, against,
# Nearest to he: she, it, they, there, who, dysprosium, then, jackson,
# Nearest to this: it, which, the, some, any, another, he, begins,
# Nearest to if: when, where, though, before, after, presupposition, unless, since,
# Nearest to three: two, four, five, seven, eight, six, nine, one,
# Average loss at step 92000: 3.397055
# Average loss at step 94000: 3.258393
# Average loss at step 96000: 3.358172
# Average loss at step 98000: 3.241529
# Average loss at step 100000: 3.354673
# Nearest to b: d, tabular, j, deutsches, r, aboard, consolidating, c,
# Nearest to so: haploid, zhuang, too, accidental, erupt, nocs, mineralogical, then,
# Nearest to while: when, although, though, where, unlike, if, however, but,
# Nearest to has: had, have, is, was, contains, since, having, inferences,
# Nearest to more: less, most, very, extremely, rather, greater, increasingly, highly,
# Nearest to time: week, year, reason, sort, delegations, karabakh, thing, period,
# Nearest to be: refer, been, have, being, become, is, easily, are,
# Nearest to however: but, although, that, though, while, where, ethelbert, since,
# Nearest to no: any, little, skye, only, always, nothing, composers, another,
# Nearest to between: with, among, tx, within, raza, from, dvorak, actus,
# Nearest to that: which, however, what, who, why, this, censorware, because,
# Nearest to by: through, using, under, including, when, gp, mersey, lonsdaleite,
# Nearest to he: she, it, they, there, who, we, dysprosium, greenpeace,
# Nearest to this: it, which, another, some, he, that, what, the,
# Nearest to if: when, though, where, while, before, unless, presupposition, because,
# Nearest to three: five, four, seven, two, six, eight, nine, one,
# processing end

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
import numpy as np

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x,y), xytext=(5,2), textcoords='offset points',
                      ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
