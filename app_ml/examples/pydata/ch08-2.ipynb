# %%
# %matplotlib inline
import numpy as np
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
from pandas import Series
values = Series(np.concatenate([comp1, comp2]))
values.hist(bins=100, alpha=0.3, color='k')
values.plot(kind='kde', style='k--')

# %%
import pandas as pd
macro = pd.read_csv('~/Dropbox/poohdrop/mldata/pydata-book/ch08/macrodata.csv')

# %%
macro
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# 5    1960.0      2.0   2834.390    1792.9   298.152   460.400   1966.1
# 6    1960.0      3.0   2839.022    1785.8   296.375   474.676   1967.8
# 7    1960.0      4.0   2802.616    1788.2   259.764   476.434   1966.6
# 8    1961.0      1.0   2819.264    1787.7   266.405   475.854   1984.5
# 9    1961.0      2.0   2872.005    1814.3   286.246   480.328   2014.4
# 10   1961.0      3.0   2918.419    1823.1   310.227   493.828   2041.9
# 11   1961.0      4.0   2977.830    1859.6   315.463   502.521   2082.0
# ...

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data[:10]
# Out:
#      cpi     m1  tbilrate  unemp
# 0  28.98  139.7      2.82    5.8
# 1  29.15  141.7      3.08    5.1
# 2  29.35  140.5      3.82    5.3
# 3  29.37  140.0      4.33    5.6
# 4  29.54  139.6      3.50    5.2
# 5  29.55  140.2      2.68    5.2
# 6  29.75  140.9      2.36    5.6
# 7  29.84  141.1      2.29    6.3
# 8  29.81  142.1      2.37    6.8
# 9  29.92  142.9      2.29    7.0

# %%
trans_data_1 = np.log(data)
trans_data_1[:10]
# Out:
#         cpi        m1  tbilrate     unemp
# 0  3.366606  4.939497  1.036737  1.757858
# 1  3.372455  4.953712  1.124930  1.629241
# 2  3.379293  4.945207  1.340250  1.667707
# 3  3.379974  4.941642  1.465568  1.722767
# 4  3.385745  4.938781  1.252763  1.648659
# 5  3.386084  4.943070  0.985817  1.648659
# 6  3.392829  4.948050  0.858662  1.722767
# 7  3.395850  4.949469  0.828552  1.840550
# 8  3.394844  4.956531  0.862890  1.916923
# 9  3.398527  4.962145  0.828552  1.945910

# %%
trans_data_2 = trans_data_1.diff()
trans_data_2[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
help(trans_data_1.diff)
# Out:
# Help on method diff in module pandas.core.frame:
#
# diff(self, periods=1, axis=0) method of pandas.core.frame.DataFrame instance
#     1st discrete difference of object
#
#     Parameters
#     ----------
#     periods : int, default 1
#         Periods to shift for forming difference
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Take difference over rows (0) or columns (1).
#
#         .. versionadded: 0.16.1
#
#     Returns
#     -------
#     diffed : DataFrame

# %%
ls
# Out:
# ch08-2.ipynb  ch08.ipynb    spx.csv*      tips.csv*

# %%
# !head tips.csv
# Out:
# total_bill,tip,sex,smoker,day,time,size
# 16.99,1.01,Female,No,Sun,Dinner,2
# 10.34,1.66,Male,No,Sun,Dinner,3
# 21.01,3.5,Male,No,Sun,Dinner,3
# 23.68,3.31,Male,No,Sun,Dinner,2
# 24.59,3.61,Female,No,Sun,Dinner,4
# 25.29,4.71,Male,No,Sun,Dinner,4
# 8.77,2.0,Male,No,Sun,Dinner,2
# 26.88,3.12,Male,No,Sun,Dinner,4
# 15.04,1.96,Male,No,Sun,Dinner,2

# %%
ls
# Out:
# ch08-2.ipynb  ch08.ipynb    spx.csv*      tips.csv*

# %%
import pandas as pd
macro = pd.read_csv('/Users/user/Dropbox/poohdrop/mldata/pydata-book/ch08/macrodata.csv')

# %%
macro.describe()
# Out:
#               year     quarter       realgdp     realcons      realinv  \
# count   203.000000  203.000000    203.000000   203.000000   203.000000
# mean   1983.876847    2.492611   7221.171901  4825.293103  1012.863862
# std      14.686817    1.118563   3214.956044  2313.346192   585.102267
# min    1959.000000    1.000000   2710.349000  1707.400000   259.764000
# 25%    1971.000000    1.500000   4440.103500  2874.100000   519.147500
# 50%    1984.000000    2.000000   6559.594000  4299.900000   896.210000
# 75%    1996.500000    3.000000   9629.346500  6398.150000  1436.681500
# max    2009.000000    4.000000  13415.266000  9363.600000  2264.721000
#
#           realgovt       realdpi         cpi           m1    tbilrate  \
# count   203.000000    203.000000  203.000000   203.000000  203.000000
# mean    663.328640   5310.540887  105.075788   667.927586    5.311773
# std     140.863655   2423.515977   61.278878   455.346381    2.803071
# ...

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

# %%
import numpy as np
trans_data = np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
pd.scatter_matrix(trans_data, diagonal='kde', c='k', alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a2f8c10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b3e06d0>]], dtype=object)

# %%
# %matplotlib inline
